# %%
# !pip install yfinance pmdarima statsmodels

# %%
from kaggle_secrets import UserSecretsClient
IEX_CLOUD_API_TOKEN = UserSecretsClient().get_secret('iex_api_tokene')
import requests
import numpy as np
import pandas as pd
from scipy import stats 
import yfinance
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statistics import mean

# %%
#text file with names off all top 500 stocks
with open('/kaggle/input/stock-symbols/s_and_p_500_symbols.txt') as f:
    symbols = np.array(f.read().splitlines())

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]
symbol_groups = list(chunks(symbols, 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))

# %%
stock_columns = [
                'Ticker', 
                'Price', 
                'Number of Shares to Buy', 
                'One-Year Price Return', 
                'One-Year Return Percentile',
                'Six-Month Price Return',
                'Six-Month Return Percentile',
                'Three-Month Price Return',
                'Three-Month Return Percentile',
                'One-Month Price Return',
                'One-Month Return Percentile',
                'Price-to-Earnings Ratio', 
                'HQM Score'
                ]

stock_data = pd.DataFrame(columns = stock_columns)

# %%
for symbol_string in symbol_strings:  
    #api request to iex cloud 
    data = requests.get(f'https://cloud.iexapis.com/v1/stock/market/batch/?types=stats,quote&symbols={symbol_string}&token={IEX_CLOUD_API_TOKEN}').json()
    for symbol in symbol_string.split(','):
        #iex can only retreive 100 company info per batch so 100 company batch is created
        if symbol == '':
            continue
        stock_data = stock_data.append(
                                    pd.Series([symbol, 
                                               data[symbol]['quote']['latestPrice'],
                                               'N/A',
                                               data[symbol]['stats']['year1ChangePercent'],
                                               'N/A',
                                               data[symbol]['stats']['month6ChangePercent'],
                                               'N/A',
                                               data[symbol]['stats']['month3ChangePercent'],
                                               'N/A',
                                               data[symbol]['stats']['month1ChangePercent'],
                                               'N/A',
                                               data[symbol]['quote']['peRatio'],
                                               'N/A'
                                               ], 
                                              index = stock_columns), 
                                        ignore_index = True)

# %%
time_periods = [
                'One-Year',
                'Six-Month',
                'Three-Month',
                'One-Month'
                ]

for row in stock_data.index:
    for time_period in time_periods:
        stock_data.loc[row, f'{time_period} Return Percentile'] = stats.percentileofscore(stock_data[f'{time_period} Price Return'], stock_data.loc[row, f'{time_period} Price Return'])/100

# %%
#getting all the percentile and taking mean of it
for row in stock_data.index:
    momentum_percentiles = []
    for time_period in time_periods:
        momentum_percentiles.append(stock_data.loc[row, f'{time_period} Return Percentile'])
    stock_data.loc[row, 'HQM Score'] = mean(momentum_percentiles)

# %%
stock_data = stock_data.sort_values(by='HQM Score', ascending=False)
best_momentum_stock = stock_data[:5]['Ticker']
stock_data = stock_data.sort_values(by='Price-to-Earnings Ratio', ascending=False)
best_value_stock = stock_data[:5]['Ticker']
#top 10 stocks by using both stratergy
ticker_data = np.append(best_momentum_stock.to_numpy(),best_value_stock.to_numpy())

# %%
ticker_returns={}
for ticker in ticker_data:
    #use yahoo finance api to get info of a company
    getCompanyInfo = yfinance.Ticker(ticker)
    #1 month interval stock data 
    data_train = getCompanyInfo.history(period="max",interval='1mo')
    data_train.reset_index(inplace=True)
    #removing time from date column
    data_train['Date'] = data_train['Date'].dt.date
    data_train.set_index('Date', inplace=True)
    #consider only closing price
    train = data_train['Close']
    #basic arima model
    model_arima= auto_arima(train,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,
                  suppress_warnings=True,stepwise=False,seasonal=False)
    #5 year forecasting
    prediction = model_arima.predict(n_periods=60)
    #calculating profit or loss
    profit_or_loss = ((prediction[-1] * 100)/train.iloc[-1]) - 100
    ticker_returns[ticker]=profit_or_loss
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1685.016, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1684.481, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1685.920, Time=0.18 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1684.448, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1684.891, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1686.301, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1687.619, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1685.918, Time=0.31 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1684.968, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1686.782, Time=0.21 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1663.872, Time=0.60 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1685.947, Time=0.21 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1685.855, Time=0.32 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1665.630, Time=0.68 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 4.282 seconds
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1855.705, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1857.159, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1857.210, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1856.948, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1857.064, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1857.289, Time=0.24 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1857.089, Time=0.37 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1858.305, Time=0.63 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1857.419, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1857.737, Time=0.31 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1857.424, Time=0.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1858.952, Time=0.33 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.79 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 4.827 seconds
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1351.648, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(0,2,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1270.214, Time=0.12 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1252.091, Time=0.12 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=1229.839, Time=0.28 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.84 sec
#
# Best model:  ARIMA(3,2,0)(0,0,0)[0] intercept
# Total fit time: 9.158 seconds
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1878.404, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1643.132, Time=0.17 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=1639.913, Time=0.22 sec
#  ARIMA(0,2,3)(0,0,0)[0] intercept   : AIC=1641.061, Time=0.30 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1780.576, Time=0.11 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1640.644, Time=0.21 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=1615.427, Time=0.42 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1671.665, Time=0.14 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=1639.333, Time=0.29 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=1613.261, Time=0.42 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=1615.226, Time=0.82 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=1673.478, Time=0.17 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=1626.220, Time=0.42 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=1614.902, Time=0.50 sec
#
# Best model:  ARIMA(2,2,2)(0,0,0)[0] intercept
# Total fit time: 4.586 seconds
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2644.407, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,2,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=2528.617, Time=0.11 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=2476.984, Time=0.15 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=2461.013, Time=0.33 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.88 sec
#
# Best model:  ARIMA(3,2,0)(0,0,0)[0] intercept
# Total fit time: 8.095 seconds
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1673.351, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1674.607, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1676.471, Time=0.16 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1672.529, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1674.655, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1674.627, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1676.556, Time=0.26 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1674.349, Time=0.34 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1676.261, Time=0.13 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1676.132, Time=0.30 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1673.928, Time=0.16 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1675.923, Time=0.32 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1669.943, Time=0.74 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 4.515 seconds
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2442.993, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2432.938, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2433.334, Time=0.21 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2430.451, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2435.247, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2434.167, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2425.432, Time=0.28 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2426.943, Time=0.40 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2431.513, Time=0.19 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2425.255, Time=0.30 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2426.961, Time=0.66 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2427.919, Time=0.86 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2432.651, Time=0.26 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2427.027, Time=0.78 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2429.254, Time=0.48 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 5.099 seconds
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1169.307, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1171.086, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1167.189, Time=0.13 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1166.547, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1170.991, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1171.105, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1166.618, Time=0.27 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1168.324, Time=0.48 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1167.227, Time=0.29 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1167.920, Time=0.30 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1167.398, Time=0.48 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1170.249, Time=0.30 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1167.596, Time=0.13 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1169.528, Time=0.25 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1169.224, Time=0.47 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0] intercept
# Total fit time: 3.715 seconds
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1799.684, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1792.871, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1784.844, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1758.892, Time=0.26 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1796.490, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1792.967, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1756.472, Time=0.33 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1756.059, Time=0.34 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1779.449, Time=0.13 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1756.658, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1757.359, Time=0.34 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1756.917, Time=0.42 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1772.985, Time=0.14 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1759.919, Time=0.68 sec
#
# Best model:  ARIMA(1,1,3)(0,0,0)[0] intercept
# Total fit time: 4.143 seconds
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2677.399, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2679.154, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2680.365, Time=0.27 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2681.580, Time=0.32 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2679.130, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2679.118, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2680.389, Time=0.39 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2682.041, Time=0.44 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2680.244, Time=0.15 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2680.447, Time=0.33 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2680.104, Time=0.59 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2683.924, Time=0.50 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2681.298, Time=0.19 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2682.176, Time=0.39 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.87 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 5.050 seconds

# %%
print(ticker_returns)
# Out:
# {'FSLR': 19.44959581771147,
#  'WYNN': 23.003338393969017,
#  'ACGL': 147.34891835000826,
#  'STLD': 203.80451932749492,
#  'URI': 344.3600109995355,
#  'CRM': -9.935263866024059,
#  'STZ': 17.390398860674807,
#  'NOW': 43.07101568199613,
#  'GPN': 24.987077022125405,
#  'MHK': 15.024757270256217}
